# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
df = pd.read_csv("AugmentedExercises.csv")
df['SecondaryMuscles'] = df['SecondaryMuscles'].fillna('')
df.head()
# Out:
#                            Title  \
# 0               Barbell roll-out
# 1  Barbell Ab Rollout - On Knees
# 2       Dumbbell V-Sit Cross Jab
# 3          Dumbbell spell caster
# 4                 Landmine twist
#
#                                                 Desc      Type    BodyPart  \
# 0  The barbell roll-out is an abdominal exercise ...  Strength  Abdominals
# 1  The barbell roll-out is an abdominal exercise ...  Strength  Abdominals
# 2  The dumbbell V-sit cross jab is a hybrid movem...  Strength  Abdominals
# 3  The dumbbell spell caster is an exercise that ...  Strength  Abdominals
# 4  The landmine twist is a rotational abdominal m...  Strength  Abdominals
#
#   Equipment         Level  Rating Movement MovementType Intensity InjuryRisk  \
# 0   Barbell  Intermediate     8.9     core    Isolation      High        Low
# 1   Barbell  Intermediate     8.9     core    Isolation      High        Low
# 2  Dumbbell  Intermediate     9.3     core    Isolation    Medium        Low
# 3  Dumbbell      Beginner     9.3     core    Isolation    Medium        Low
# 4     Other  Intermediate     9.5     core    Isolation       Low        Low
#
#   SecondaryMuscles
# 0
# 1
# 2
# 3         Obliques
# 4         Obliques

# %%
df['BodyPart_feature'] = ['BodyPart_{}'.format(x) for x in df['BodyPart']]
df['Movement_feature'] = ['Movement_{}'.format(x) for x in df['Movement']]
df['Level_feature'] = ['Level_{}'.format(x) for x in df['Level']]
df['SecondaryMuscles_feature'] = ['SecondaryMuscles_{}'.format(x) for x in df['SecondaryMuscles']]

df['corpus'] = (pd.Series(df[['BodyPart_feature', 'Movement_feature', "Level_feature", "SecondaryMuscles_feature", 'Desc']]
                .fillna('')
                .values.tolist()
                ).str.join(' '))

# %%
# Create a TfidfVectorizer and Remove stopwords
tfidf = TfidfVectorizer(stop_words='english')
# Fit and transform the data to a tfidf matrix
desc_matrix = tfidf.fit_transform(df['corpus'])
# Print the shape of the tfidf_matrix
desc_matrix.shape
# Out:
# (207, 1038)

# %%
# Compute the cosine similarity between each movie description
cosine_sim = linear_kernel(desc_matrix, desc_matrix)

# %%
indices = pd.Series(df.index, index=df['Title']).drop_duplicates()

# %%
def get_recommendations(title, cosine_sim=cosine_sim, num_recommend = 10):
    idx = indices[title]
    # Get the pairwsie similarity scores of all exercises with that exercise
    sim_scores = list(enumerate(cosine_sim[idx]))
    # Sort the exercises based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    # Get the scores of the 10 most similar exercises
    top_similar = sim_scores[1:num_recommend+1]
    # Get the exercise indices
    exercise_indices = [i[0] for i in top_similar]
    # Return the top 10 most similar exercises
    return df.iloc[exercise_indices]

# %%
get_recommendations('Pushups', num_recommend = 10)
# Out:
#                                        Title  \
# 102                                  Pullups
# 103                                  Pull-up
# 157                           Military press
# 58   Barbell Incline Bench Press Medium-Grip
# 68              Incline dumbbell bench press
# 74             Close-grip EZ-bar bench press
# 201        Push-Ups - Close Triceps Position
# 75                                 Chest dip
# 56               Decline barbell bench press
# 109                    Bent Over Barbell Row
#
#                                                   Desc      Type     BodyPart  \
# 102  The pull-up is a multi-joint bodyweight exerci...  Strength         Lats
# 103  The pull-up is a multijoint bodyweight exercis...  Strength         Lats
# 157  The military press is a compound movement used...  Strength    Shoulders
# 58   The incline bench press is an upper body compo...  Strength        Chest
# 68   The incline dumbbell bench press is a popular ...  Strength        Chest
# 74   The close-grip EZ-bar bench press is an exerci...  Strength        Chest
# 201  The close push-up is an upper-body exercise th...  Strength      Triceps
# 75   The chest dip is a bodyweight exercise perform...  Strength        Chest
# 56   The decline barbell bench press is a popular u...  Strength        Chest
# 109  The barbell bent-over row is a compound exerci...  Strength  Middle Back
#
#         Equipment         Level  Rating Movement MovementType Intensity  \
# 102     Body Only  Intermediate     9.2     pull    Isolation       Low
# 103     Body Only      Beginner     8.9     pull    Isolation       Low
# 157       Barbell  Intermediate     9.3     push     Compound      High
# 58        Barbell  Intermediate     8.8     push     Compound      High
# 68       Dumbbell  Intermediate     9.1     push    Isolation    Medium
# 74   E-Z Curl Bar  Intermediate     8.8     push    Isolation       Low
# 201     Body Only  Intermediate     9.0     push    Isolation       Low
# 75          Other  Intermediate     9.0     push    Isolation       Low
# 56        Barbell  Intermediate     8.9     push    Isolation      High
# 109       Barbell  Intermediate     8.7     pull     Compound      High
#
#     InjuryRisk    SecondaryMuscles      BodyPart_feature Movement_feature  \
# 102        Low                             BodyPart_Lats    Movement_pull
# 103        Low                             BodyPart_Lats    Movement_pull
# 157        Low                        BodyPart_Shoulders    Movement_push
# 58         Low                            BodyPart_Chest    Movement_push
# 68         Low                            BodyPart_Chest    Movement_push
# 74         Low  Triceps, Shoulders        BodyPart_Chest    Movement_push
# 201        Low                          BodyPart_Triceps    Movement_push
# 75         Low  Triceps, Shoulders        BodyPart_Chest    Movement_push
# 56         Low                            BodyPart_Chest    Movement_push
# 109        Low                      BodyPart_Middle Back    Movement_pull
#
#                                                 corpus       Level_feature  \
# 102  The pull-up is a multi-joint bodyweight exerci...  Level_Intermediate
# 103  The pull-up is a multijoint bodyweight exercis...      Level_Beginner
# 157  The military press is a compound movement used...  Level_Intermediate
# 58   The incline bench press is an upper body compo...  Level_Intermediate
# 68   The incline dumbbell bench press is a popular ...  Level_Intermediate
# 74   The close-grip EZ-bar bench press is an exerci...  Level_Intermediate
# 201  The close push-up is an upper-body exercise th...  Level_Intermediate
# 75   The chest dip is a bodyweight exercise perform...  Level_Intermediate
# 56   The decline barbell bench press is a popular u...  Level_Intermediate
# 109  The barbell bent-over row is a compound exerci...  Level_Intermediate
#
#                 SecondaryMuscles_feature
# 102                    SecondaryMuscles_
# 103                    SecondaryMuscles_
# 157                    SecondaryMuscles_
# 58                     SecondaryMuscles_
# 68                     SecondaryMuscles_
# 74   SecondaryMuscles_Triceps, Shoulders
# 201                    SecondaryMuscles_
# 75   SecondaryMuscles_Triceps, Shoulders
# 56                     SecondaryMuscles_
# 109                    SecondaryMuscles_
